# %%
from langchain_community.embeddings import OllamaEmbeddings

# %%
Embed = (
  OllamaEmbeddings(model = "gemma:2b")  
)

# %%
Embed
# Out:
# OllamaEmbeddings(base_url='http://localhost:11434', model='gemma:2b', embed_instruction='passage: ', query_instruction='query: ', mirostat=None, mirostat_eta=None, mirostat_tau=None, num_ctx=None, num_gpu=None, num_thread=None, repeat_last_n=None, repeat_penalty=None, temperature=None, stop=None, tfs_z=None, top_k=None, top_p=None, show_progress=False, headers=None, model_kwargs=None)

# %%
r1 = Embed.embed_documents([
  "Hello my name is Aditya",
  "Hello my name is Adrish",  
])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 r1 = Embed.embed_documents([
#       2   "Hello my name is Aditya",
#       3   "Hello my name is Adrish",
#       4 ])
#
# File d:\Anaconda\envs\myenv\lib\site-packages\langchain_community\embeddings\ollama.py:214, in OllamaEmbeddings.embed_documents(self, texts)
#     205 """Embed documents using an Ollama deployed embedding model.
#     206
#     207 Args:
#    (...)
#     211     List of embeddings, one for each text.
#     212 """
#     213 instruction_pairs = [f"{self.embed_instruction}{text}" for text in texts]
# --> 214 embeddings = self._embed(instruction_pairs)
#     215 return embeddings
#
# File d:\Anaconda\envs\myenv\lib\site-packages\langchain_community\embeddings\ollama.py:202, in OllamaEmbeddings._embed(self, input)
#     200 else:
#     201     iter_ = input
# ...
