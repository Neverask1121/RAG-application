# %%
import pandas as pd

# %%
df = pd.read_csv("pokemon_data.csv")
print(df)
# Out:
#      Pokedex_Number       Name  Type_1 Type_2   HP  Attack  Defense
# 0                 1  Bulbasaur  Dragon    NaN   44     136      101
# 1                 1  Bulbasaur  Dragon    NaN   44     136      101
# 2                 1  Bulbasaur  Dragon    NaN   44     136      101
# 3                 1  Bulbasaur  Dragon    NaN   44     136      101
# 4                 1  Bulbasaur  Dragon    NaN   44     136      101
# ..              ...        ...     ...    ...  ...     ...      ...
# 149             146    Moltres    Fire  Water   50      99       99
# 150             147    Dratini     Bug    Ice  104      91       91
# 151             148  Dragonair   Fairy  Grass   60      69      130
# 152             149  Dragonite     Ice   Rock  104      33      108
# 153             150     Mewtwo   Ghost  Steel   91      86       95
#
# [154 rows x 7 columns]

# %%
print(df["HP"].count())
# Out:
# 154

# %%
group = df.groupby("Type_1")

# %%
print(group["HP"].max())
# Out:
# Type_1
# Bug         157
# Dark        147
# Dragon      158
# Electric    103
# Fairy       128
# Fighting    144
# Fire        157
# Flying      159
# Ghost       144
# Grass       130
# Ground      138
# Ice         141
# Normal      149
# Poison      142
# Psychic     158
# Rock        140
# Steel       111
# Water       159
# Name: HP, dtype: int64

# %%
# df = df.drop(columns = ["HP", "Pokedex_Number"])

# %%
# df = df.dropna(subset=["Type_2"])

# %%
# df = df.fillna({"Type_2":"None"})

# %%
# df["Type_1"]=df["Type_1"].replace({"Grass":"GRASS", "Dragon":"DRAGON", "Bug":"BUG"})

# %%
df["Name"]=df["Name"].str.lower()

# %%
df = df.drop_duplicates()

# %%
print(df.to_string())
# Out:
#      Pokedex_Number        Name    Type_1    Type_2   HP  Attack  Defense
# 0                 1   bulbasaur    Dragon       NaN   44     136      101
# 5                 2     ivysaur    Dragon     Ghost  104     104      117
# 6                 3    venusaur  Electric       Ice   82      31      117
# 7                 4  charmander       Ice      Fire   50      62      105
# 8                 5  charmeleon    Flying      Fire   88      71      121
# 9                 6   charizard       Bug      Dark   80     137       84
# 10                7    squirtle     Grass       NaN   50     102       68
# 11                8   wartortle  Electric       NaN   43     143       38
# 12                9   blastoise     Water       NaN  140      89      100
# 13               10    caterpie      Dark     Water  110      65       79
# 14               11     metapod  Electric    Flying   83     135       33
# 15               12  butterfree     Steel       NaN   43     124       77
# 16               13      weedle      Dark       NaN   69     114      109
# 17               14      kakuna     Steel       NaN   53      55      118
# 18               15    beedrill    Poison   Psychic   44      74       94
# 19               16      pidgey    Dragon       Bug  158     137       37
# 20               17   pidgeotto  Fighting    Dragon   62      34      135
# 21               18     pidgeot     Fairy       NaN  101      41       63
# 22               19     rattata       Bug    Poison   91     117       66
# 23               20    raticate    Flying       NaN   64      94      128
# 24               21     spearow      Rock       NaN   30      34      119
# 25               22      fearow    Ground     Steel   44     119       71
# 26               23       ekans    Dragon     Steel  125      33      123
# 27               24       arbok    Dragon      Rock   58      65       42
# 28               25     pikachu    Dragon  Fighting  115      57       95
# 29               26      raichu    Poison  Fighting   57      57      137
# 30               27   sandshrew  Fighting    Poison  121     118      132
# 31               28   sandslash      Fire  Fighting   56      91      145
# 32               29    nidoran♀     Fairy    Flying   91      66      126
# 33               30    nidorina    Normal    Poison   88     147       61
# 34               31   nidoqueen     Fairy      Rock   91     142       87
# 35               32    nidoran♂    Flying     Fairy  159      32      142
# 36               33    nidorino     Ghost       NaN  142      31       31
# 37               34    nidoking   Psychic    Poison  158      48       31
# 38               35    clefairy    Flying     Ghost   97      84      104
# 39               36    clefable     Ghost       NaN   53      98      145
# 40               37      vulpix       Ice      Rock  126     102       88
# 41               38   ninetales       Bug     Water  119      96       48
# 42               39  jigglypuff    Dragon       Ice  157      68      111
# 43               40  wigglytuff      Fire       NaN   71     128       36
# 44               41       zubat       Bug       NaN   89     142       31
# 45               42      golbat       Bug       NaN   66      61      148
# 46               43      oddish     Fairy    Poison   77     109       32
# 47               44       gloom      Fire       NaN  104     142      101
# 48               45   vileplume       Ice       NaN  141     118      128
# 49               46       paras     Steel       Ice  111      95       83
# 50               47    parasect       Bug       NaN   97      62       43
# 51               48     venonat       Bug       NaN  157      37       36
# 52               49    venomoth     Ghost  Fighting  144     115      148
# 53               50     diglett    Ground       NaN  138      80       83
# 54               51     dugtrio     Water    Poison  126      57      140
# 55               52      meowth      Fire      Dark   90      77       48
# 56               53     persian     Grass       NaN   46      73      121
# 57               54     psyduck    Ground       NaN  128     134       66
# 58               55     golduck     Ghost       NaN  124     128       89
# 59               56      mankey      Fire    Flying  157      47       54
# 60               57    primeape     Grass       NaN   53     143       61
# 61               58   growlithe     Water    Normal  159     119       46
# 62               59    arcanine      Fire       Ice   68     122       71
# 63               60     poliwag     Grass    Normal   42      89       36
# 64               61   poliwhirl  Electric       NaN   94      37      139
# 65               62   poliwrath    Ground       NaN  121     127       95
# 66               63        abra     Ghost     Water   99      44       83
# 67               64     kadabra   Psychic       NaN   82      89      137
# 68               65    alakazam   Psychic     Ghost   35     138      125
# 69               66      machop      Rock       NaN   81      45       42
# 70               67     machoke    Normal    Flying  149      92       48
# 71               68     machamp   Psychic      Dark   91      52       38
# 72               69  bellsprout      Fire    Dragon   30     140       63
# 73               70  weepinbell       Bug    Dragon  146      30       45
# 74               71  victreebel    Dragon       NaN   98      51      122
# 75               72   tentacool     Grass    Normal  115      86       58
# 76               73  tentacruel   Psychic  Electric  123     139       91
# 77               74     geodude   Psychic     Steel  114      68      129
# 78               75    graveler   Psychic      Rock   39     147       98
# 79               76       golem     Water    Normal  125      30      149
# 80               77      ponyta    Poison       Ice   53     109      148
# 81               78    rapidash     Ghost       NaN  113      53       41
# 82               79    slowpoke     Grass       NaN  130      41       96
# 83               80     slowbro      Fire       NaN   72      73       58
# 84               81   magnemite    Flying  Electric  159     144      143
# 85               82    magneton     Ghost       NaN  122      55      103
# 86               83  farfetch'd     Water    Normal   87     146      143
# 87               84       doduo  Fighting       NaN   50      65       39
# 88               85      dodrio     Fairy       NaN  128     141       65
# 89               86        seel     Ghost       NaN   66      41      142
# 90               87     dewgong    Poison       NaN  128     134       59
# 91               88      grimer     Ghost       NaN  141     118      115
# 92               89         muk     Ghost     Water  105      38      100
# 93               90    shellder    Ground       NaN   81     112      140
# 94               91    cloyster   Psychic  Fighting   54      81      114
# 95               92      gastly       Bug       NaN  138      82       71
# 96               93     haunter    Dragon       NaN  151      34       64
# 97               94      gengar  Fighting       NaN  105      38      103
# 98               95        onix    Flying       NaN   36      75       42
# 99               96     drowzee    Normal      Rock   56      95       34
# 100              97       hypno   Psychic     Fairy  138      94      115
# 101              98      krabby     Ghost       NaN   74      33       65
# 102              99     kingler    Flying       NaN  120     103      119
# 103             100     voltorb    Dragon       Bug  155      87       49
# 104             101   electrode      Dark  Electric  134      68       30
# 105             102   exeggcute    Poison     Fairy  142      54       85
# 106             103   exeggutor       Ice       Bug   87      73       74
# 107             104      cubone    Poison     Water  109     147      114
# 108             105     marowak   Psychic    Normal   49      86       47
# 109             106   hitmonlee     Fairy      Dark   30     146       83
# 110             107  hitmonchan     Grass       NaN   41     103      125
# 111             108   lickitung      Dark      Rock  146      37      121
# 112             109     koffing      Dark    Ground   57     121      130
# 113             110     weezing  Electric       NaN   75      64       35
# 114             111     rhyhorn   Psychic       NaN   39      85       59
# 115             112      rhydon    Poison       Ice   62     147       94
# 116             113     chansey      Rock       Ice  114      55       92
# 117             114     tangela     Ghost       NaN  127     134      128
# 118             115  kangaskhan       Bug     Grass  124      34      131
# 119             116      horsea   Psychic       NaN  112      46      114
# 120             117      seadra     Fairy   Psychic   80      74      106
# 121             118     goldeen      Fire       NaN   61      63      121
# 122             119     seaking      Dark      Fire  147      32       79
# 123             120      staryu      Fire       NaN   86      46      141
# 124             121     starmie      Rock       NaN   95     104       80
# 125             122    mr. mime       Ice       NaN   67      79      127
# 126             123     scyther      Rock       Bug   81      67      126
# 127             124        jynx      Rock    Ground  135      80      110
# 128             125  electabuzz  Electric     Ghost  103      46      113
# 129             126      magmar   Psychic       NaN   82      95      106
# 130             127      pinsir  Fighting     Fairy  144     140       52
# 131             128      tauros       Bug       Ice  147      45       37
# 132             129    magikarp      Dark       NaN   54      96      125
# 133             130    gyarados     Steel       NaN   80      48       50
# 134             131      lapras     Steel    Normal   90      51       50
# 135             132       ditto      Fire       NaN   41     119       75
# 136             133       eevee     Ghost       NaN   74      56      102
# 137             134    vaporeon      Rock       NaN   85     123      136
# 138             135     jolteon       Bug     Grass   55      65       30
# 139             136     flareon     Ghost       NaN   76      85      115
# 140             137     porygon    Ground     Ghost  138      55       43
# 141             138     omanyte    Dragon       NaN  136     140      138
# 142             139     omastar       Ice       NaN   44      93      118
# 143             140      kabuto   Psychic      Dark   68      86       46
# 144             141    kabutops    Flying      Dark   42     113       54
# 145             142  aerodactyl    Normal       NaN  138      47      140
# 146             143     snorlax      Rock       NaN  140      37       69
# 147             144    articuno    Flying   Psychic  130      35       81
# 148             145      zapdos     Water    Normal   88     138       99
# 149             146     moltres      Fire     Water   50      99       99
# 150             147     dratini       Bug       Ice  104      91       91
# 151             148   dragonair     Fairy     Grass   60      69      130
# 152             149   dragonite       Ice      Rock  104      33      108
# 153             150      mewtwo     Ghost     Steel   91      86       95

# %%
print(df.to_string())
# Out:
#      Pokedex_Number        Name    Type_1    Type_2   HP  Attack  Defense
# 0                 1   bulbasaur    Dragon       NaN   44     136      101
# 1                 1   bulbasaur    Dragon       NaN   44     136      101
# 2                 1   bulbasaur    Dragon       NaN   44     136      101
# 3                 1   bulbasaur    Dragon       NaN   44     136      101
# 4                 1   bulbasaur    Dragon       NaN   44     136      101
# 5                 2     ivysaur    Dragon     Ghost  104     104      117
# 6                 3    venusaur  Electric       Ice   82      31      117
# 7                 4  charmander       Ice      Fire   50      62      105
# 8                 5  charmeleon    Flying      Fire   88      71      121
# 9                 6   charizard       Bug      Dark   80     137       84
# 10                7    squirtle     Grass       NaN   50     102       68
# 11                8   wartortle  Electric       NaN   43     143       38
# 12                9   blastoise     Water       NaN  140      89      100
# 13               10    caterpie      Dark     Water  110      65       79
# 14               11     metapod  Electric    Flying   83     135       33
# 15               12  butterfree     Steel       NaN   43     124       77
# 16               13      weedle      Dark       NaN   69     114      109
# 17               14      kakuna     Steel       NaN   53      55      118
# 18               15    beedrill    Poison   Psychic   44      74       94
# 19               16      pidgey    Dragon       Bug  158     137       37
# 20               17   pidgeotto  Fighting    Dragon   62      34      135
# 21               18     pidgeot     Fairy       NaN  101      41       63
# 22               19     rattata       Bug    Poison   91     117       66
# 23               20    raticate    Flying       NaN   64      94      128
# 24               21     spearow      Rock       NaN   30      34      119
# 25               22      fearow    Ground     Steel   44     119       71
# 26               23       ekans    Dragon     Steel  125      33      123
# 27               24       arbok    Dragon      Rock   58      65       42
# 28               25     pikachu    Dragon  Fighting  115      57       95
# 29               26      raichu    Poison  Fighting   57      57      137
# 30               27   sandshrew  Fighting    Poison  121     118      132
# 31               28   sandslash      Fire  Fighting   56      91      145
# 32               29    nidoran♀     Fairy    Flying   91      66      126
# 33               30    nidorina    Normal    Poison   88     147       61
# 34               31   nidoqueen     Fairy      Rock   91     142       87
# 35               32    nidoran♂    Flying     Fairy  159      32      142
# 36               33    nidorino     Ghost       NaN  142      31       31
# 37               34    nidoking   Psychic    Poison  158      48       31
# 38               35    clefairy    Flying     Ghost   97      84      104
# 39               36    clefable     Ghost       NaN   53      98      145
# 40               37      vulpix       Ice      Rock  126     102       88
# 41               38   ninetales       Bug     Water  119      96       48
# 42               39  jigglypuff    Dragon       Ice  157      68      111
# 43               40  wigglytuff      Fire       NaN   71     128       36
# 44               41       zubat       Bug       NaN   89     142       31
# 45               42      golbat       Bug       NaN   66      61      148
# 46               43      oddish     Fairy    Poison   77     109       32
# 47               44       gloom      Fire       NaN  104     142      101
# 48               45   vileplume       Ice       NaN  141     118      128
# 49               46       paras     Steel       Ice  111      95       83
# 50               47    parasect       Bug       NaN   97      62       43
# 51               48     venonat       Bug       NaN  157      37       36
# 52               49    venomoth     Ghost  Fighting  144     115      148
# 53               50     diglett    Ground       NaN  138      80       83
# 54               51     dugtrio     Water    Poison  126      57      140
# 55               52      meowth      Fire      Dark   90      77       48
# 56               53     persian     Grass       NaN   46      73      121
# 57               54     psyduck    Ground       NaN  128     134       66
# 58               55     golduck     Ghost       NaN  124     128       89
# 59               56      mankey      Fire    Flying  157      47       54
# 60               57    primeape     Grass       NaN   53     143       61
# 61               58   growlithe     Water    Normal  159     119       46
# 62               59    arcanine      Fire       Ice   68     122       71
# 63               60     poliwag     Grass    Normal   42      89       36
# 64               61   poliwhirl  Electric       NaN   94      37      139
# 65               62   poliwrath    Ground       NaN  121     127       95
# 66               63        abra     Ghost     Water   99      44       83
# 67               64     kadabra   Psychic       NaN   82      89      137
# 68               65    alakazam   Psychic     Ghost   35     138      125
# 69               66      machop      Rock       NaN   81      45       42
# 70               67     machoke    Normal    Flying  149      92       48
# 71               68     machamp   Psychic      Dark   91      52       38
# 72               69  bellsprout      Fire    Dragon   30     140       63
# 73               70  weepinbell       Bug    Dragon  146      30       45
# 74               71  victreebel    Dragon       NaN   98      51      122
# 75               72   tentacool     Grass    Normal  115      86       58
# 76               73  tentacruel   Psychic  Electric  123     139       91
# 77               74     geodude   Psychic     Steel  114      68      129
# 78               75    graveler   Psychic      Rock   39     147       98
# 79               76       golem     Water    Normal  125      30      149
# 80               77      ponyta    Poison       Ice   53     109      148
# 81               78    rapidash     Ghost       NaN  113      53       41
# 82               79    slowpoke     Grass       NaN  130      41       96
# 83               80     slowbro      Fire       NaN   72      73       58
# 84               81   magnemite    Flying  Electric  159     144      143
# 85               82    magneton     Ghost       NaN  122      55      103
# 86               83  farfetch'd     Water    Normal   87     146      143
# 87               84       doduo  Fighting       NaN   50      65       39
# 88               85      dodrio     Fairy       NaN  128     141       65
# 89               86        seel     Ghost       NaN   66      41      142
# 90               87     dewgong    Poison       NaN  128     134       59
# 91               88      grimer     Ghost       NaN  141     118      115
# 92               89         muk     Ghost     Water  105      38      100
# 93               90    shellder    Ground       NaN   81     112      140
# 94               91    cloyster   Psychic  Fighting   54      81      114
# 95               92      gastly       Bug       NaN  138      82       71
# 96               93     haunter    Dragon       NaN  151      34       64
# 97               94      gengar  Fighting       NaN  105      38      103
# 98               95        onix    Flying       NaN   36      75       42
# 99               96     drowzee    Normal      Rock   56      95       34
# 100              97       hypno   Psychic     Fairy  138      94      115
# 101              98      krabby     Ghost       NaN   74      33       65
# 102              99     kingler    Flying       NaN  120     103      119
# 103             100     voltorb    Dragon       Bug  155      87       49
# 104             101   electrode      Dark  Electric  134      68       30
# 105             102   exeggcute    Poison     Fairy  142      54       85
# 106             103   exeggutor       Ice       Bug   87      73       74
# 107             104      cubone    Poison     Water  109     147      114
# 108             105     marowak   Psychic    Normal   49      86       47
# 109             106   hitmonlee     Fairy      Dark   30     146       83
# 110             107  hitmonchan     Grass       NaN   41     103      125
# 111             108   lickitung      Dark      Rock  146      37      121
# 112             109     koffing      Dark    Ground   57     121      130
# 113             110     weezing  Electric       NaN   75      64       35
# 114             111     rhyhorn   Psychic       NaN   39      85       59
# 115             112      rhydon    Poison       Ice   62     147       94
# 116             113     chansey      Rock       Ice  114      55       92
# 117             114     tangela     Ghost       NaN  127     134      128
# 118             115  kangaskhan       Bug     Grass  124      34      131
# 119             116      horsea   Psychic       NaN  112      46      114
# 120             117      seadra     Fairy   Psychic   80      74      106
# 121             118     goldeen      Fire       NaN   61      63      121
# 122             119     seaking      Dark      Fire  147      32       79
# 123             120      staryu      Fire       NaN   86      46      141
# 124             121     starmie      Rock       NaN   95     104       80
# 125             122    mr. mime       Ice       NaN   67      79      127
# 126             123     scyther      Rock       Bug   81      67      126
# 127             124        jynx      Rock    Ground  135      80      110
# 128             125  electabuzz  Electric     Ghost  103      46      113
# 129             126      magmar   Psychic       NaN   82      95      106
# 130             127      pinsir  Fighting     Fairy  144     140       52
# 131             128      tauros       Bug       Ice  147      45       37
# 132             129    magikarp      Dark       NaN   54      96      125
# 133             130    gyarados     Steel       NaN   80      48       50
# 134             131      lapras     Steel    Normal   90      51       50
# 135             132       ditto      Fire       NaN   41     119       75
# 136             133       eevee     Ghost       NaN   74      56      102
# 137             134    vaporeon      Rock       NaN   85     123      136
# 138             135     jolteon       Bug     Grass   55      65       30
# 139             136     flareon     Ghost       NaN   76      85      115
# 140             137     porygon    Ground     Ghost  138      55       43
# 141             138     omanyte    Dragon       NaN  136     140      138
# 142             139     omastar       Ice       NaN   44      93      118
# 143             140      kabuto   Psychic      Dark   68      86       46
# 144             141    kabutops    Flying      Dark   42     113       54
# 145             142  aerodactyl    Normal       NaN  138      47      140
# 146             143     snorlax      Rock       NaN  140      37       69
# 147             144    articuno    Flying   Psychic  130      35       81
# 148             145      zapdos     Water    Normal   88     138       99
# 149             146     moltres      Fire     Water   50      99       99
# 150             147     dratini       Bug       Ice  104      91       91
# 151             148   dragonair     Fairy     Grass   60      69      130
# 152             149   dragonite       Ice      Rock  104      33      108
# 153             150      mewtwo     Ghost     Steel   91      86       95
