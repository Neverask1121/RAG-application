# %%
import pandas as pd

# %%
df = pd.read_csv("pokemon_data.csv")

# %%
print(df["HP"].count())
# Out:
# 150

# %%
group = df.groupby("Type_1")

# %%
print(group["HP"].max())
# Out:
# Type_1
# Bug         157
# Dark        147
# Dragon      158
# Electric    103
# Fairy       128
# Fighting    144
# Fire        157
# Flying      159
# Ghost       144
# Grass       130
# Ground      138
# Ice         141
# Normal      149
# Poison      142
# Psychic     158
# Rock        140
# Steel       111
# Water       159
# Name: HP, dtype: int64
